# %%
import pandas as pd

# %%
df = pd.read_excel('CollegeScorecardDataDictionary (1).xlsx', sheet_name= 'institution_data_dictionary')

df['dev-category'].unique()
df = df.dropna(axis=0, subset=['VARIABLE NAME'])

# %%
df[df['VARIABLE NAME'].str.contains("NPT4")]
# Out:
#                                   NAME OF DATA ELEMENT dev-category  \
# 558  Average net price for Title IV institutions (p...         cost
# 559  Average net price for Title IV institutions (p...         cost
# 560  Average net price for the largest program at t...         cost
# 561  Average net price for the largest program at t...         cost
# 562  Average net price for $0-$30,000 family income...         cost
# 563  Average net price for $30,001-$48,000 family i...         cost
# 564  Average net price for $48,001-$75,000 family i...         cost
# 565  Average net price for $75,001-$110,000 family ...         cost
# 566  Average net price for $110,000+ family income ...         cost
# 567  Average net price for $0-$30,000 family income...         cost
# 568  Average net price for $30,001-$48,000 family i...         cost
# 569  Average net price for $48,001-$75,000 family i...         cost
# 570  Average net price for $75,001-$110,000 family ...         cost
# ...

# %%
df[df['NAME OF DATA ELEMENT'].str.contains("tuition")]
df.iloc[623]
# Out:
#                                   NAME OF DATA ELEMENT dev-category  \
# 620                          In-state tuition and fees         cost
# 621                      Out-of-state tuition and fees         cost
# 623  Net tuition revenue per full-time equivalent s...       school
#
#      developer-friendly name API data type   VARIABLE NAME  VALUE LABEL  \
# 620         tuition.in_state       integer   TUITIONFEE_IN    NaN   NaN
# 621     tuition.out_of_state       integer  TUITIONFEE_OUT    NaN   NaN
# 623  tuition_revenue_per_fte       integer         TUITFTE    NaN   NaN
#
#     SOURCE                                              NOTES
# 620  IPEDS                                                NaN
# 621  IPEDS                                                NaN
# 623  IPEDS  Net tuition revenue (tuition revenue minus dis...

# %%
df[df['NAME OF DATA ELEMENT'].str.contains("price")]
# Out:
#                                   NAME OF DATA ELEMENT dev-category  \
# 9           URL for institution's net price calculator       school
# 558  Average net price for Title IV institutions (p...         cost
# 559  Average net price for Title IV institutions (p...         cost
# 560  Average net price for the largest program at t...         cost
# 561  Average net price for the largest program at t...         cost
# 562  Average net price for $0-$30,000 family income...         cost
# 563  Average net price for $30,001-$48,000 family i...         cost
# 564  Average net price for $48,001-$75,000 family i...         cost
# 565  Average net price for $75,001-$110,000 family ...         cost
# 566  Average net price for $110,000+ family income ...         cost
# 567  Average net price for $0-$30,000 family income...         cost
# 568  Average net price for $30,001-$48,000 family i...         cost
# 569  Average net price for $48,001-$75,000 family i...         cost
# ...

# %%
df2 = pd.read_csv('/airbnb/listings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f1359949f81b> in <module>
# ----> 1 df2 = pd.read_csv('/airbnb/listings.csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...
